# %% [markdown]
# # Your First AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) from Oxford of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load the image dataset and create a pipeline.
# * Build and Train an image classifier on this dataset.
# * Use your trained model to perform inference on flower images.
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.

# %%
# %pip --no-cache-dir install tfds-nightly --user
# Out:
# Collecting tfds-nightly
#   Downloading https://files.pythonhosted.org/packages/b2/a7/adaf1c6828d8c3f10c00da1763efe66a41ff71c6565a7a6b458a9d9d97ce/tfds_nightly-3.2.1.dev202007240105-py3-none-any.whl (3.4MB)
# Collecting protobuf>=3.6.1 (from tfds-nightly)
#   Downloading https://files.pythonhosted.org/packages/82/6c/c9b57d24685639dfb07b1798bf64e576c3c675a0b9fe0519254d0f9d1e30/protobuf-3.12.2-cp37-cp37m-win_amd64.whl (1.0MB)
# Requirement already satisfied: requests>=2.19.0 in c:\users\shant\anaconda3\lib\site-packages (from tfds-nightly) (2.21.0)
# Collecting tensorflow-metadata (from tfds-nightly)
#   Downloading https://files.pythonhosted.org/packages/91/94/07baf9e2a060fc5c7bd95052cc9114afd3f67b6927bd7224c0626fad5703/tensorflow_metadata-0.22.2-py2.py3-none-any.whl
# Requirement already satisfied: wrapt in c:\users\shant\anaconda3\lib\site-packages (from tfds-nightly) (1.11.1)
# Requirement already satisfied: numpy in c:\users\shant\anaconda3\lib\site-packages (from tfds-nightly) (1.16.2)
# Requirement already satisfied: tqdm in c:\users\shant\anaconda3\lib\site-packages (from tfds-nightly) (4.31.1)
# Collecting dill (from tfds-nightly)
#   Downloading https://files.pythonhosted.org/packages/e2/96/518a8ea959a734b70d2e95fef98bcbfdc7adad1c1e5f5dd9148c835205a5/dill-0.3.2.zip (177kB)
# Collecting absl-py (from tfds-nightly)
#   Downloading https://files.pythonhosted.org/packages/1a/53/9243c600e047bd4c3df9e69cfabc1e8004a82cac2e0c484580a78a94ba2a/absl-py-0.9.0.tar.gz (104kB)
# Requirement already satisfied: six in c:\users\shant\anaconda3\lib\site-packages (from tfds-nightly) (1.12.0)
# Collecting termcolor (from tfds-nightly)
#   Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Requirement already satisfied: future in c:\users\shant\anaconda3\lib\site-packages (from tfds-nightly) (0.17.1)
# Collecting promise (from tfds-nightly)
#   Downloading https://files.pythonhosted.org/packages/cf/9c/fb5d48abfe5d791cd496e4242ebcf87a4bb2e0c3dcd6e0ae68c11426a528/promise-2.3.tar.gz
# Requirement already satisfied: attrs>=18.1.0 in c:\users\shant\anaconda3\lib\site-packages (from tfds-nightly) (19.1.0)
# Requirement already satisfied: setuptools in c:\users\shant\anaconda3\lib\site-packages (from protobuf>=3.6.1->tfds-nightly) (40.8.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\shant\anaconda3\lib\site-packages (from requests>=2.19.0->tfds-nightly) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\shant\anaconda3\lib\site-packages (from requests>=2.19.0->tfds-nightly) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\shant\anaconda3\lib\site-packages (from requests>=2.19.0->tfds-nightly) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shant\anaconda3\lib\site-packages (from requests>=2.19.0->tfds-nightly) (2019.3.9)
# Collecting googleapis-common-protos (from tensorflow-metadata->tfds-nightly)
#   Downloading https://files.pythonhosted.org/packages/03/74/3956721ea1eb4bcf7502a311fdaa60b85bd751de4e57d1943afe9b334141/googleapis_common_protos-1.52.0-py2.py3-none-any.whl (100kB)
# Installing collected packages: protobuf, googleapis-common-protos, tensorflow-metadata, dill, absl-py, termcolor, promise, tfds-nightly
#   Running setup.py install for dill: started
#     Running setup.py install for dill: finished with status 'done'
#   Running setup.py install for absl-py: started
#     Running setup.py install for absl-py: finished with status 'done'
#   Running setup.py install for termcolor: started
#     Running setup.py install for termcolor: finished with status 'done'
#   Running setup.py install for promise: started
#     Running setup.py install for promise: finished with status 'done'
# Successfully installed absl-py-0.9.0 dill-0.3.2 googleapis-common-protos-1.52.0 promise-2.3 protobuf-3.12.2 tensorflow-metadata-0.22.2 termcolor-1.1.0 tfds-nightly-3.2.1.dev202007240105
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -U tensorflow
# !pip install -U tqdm
# !pip install tensorflow_datasets
# !pip install "tensorflow_hub>=0.6.0"

# %% [markdown]
# ## Import Resources

# %%
# TODO: Make all necessary imports.
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns
import IPython.display as display
from PIL import Image
import numpy as np
import pandas as pd
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-4c8ec3ad6f90> in <module>
#       1 # TODO: Make all necessary imports.
# ----> 2 import tensorflow as tf
#       3 import tensorflow_hub as hub
#       4 import tensorflow_datasets as tfds
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# ## Load the Dataset
#
# Here you'll use `tensorflow_datasets` to load the [Oxford Flowers 102 dataset](https://www.tensorflow.org/datasets/catalog/oxford_flowers102). This dataset has 3 splits: `'train'`, `'test'`, and `'validation'`.  You'll also need to make sure the training data is normalized and resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet, but you'll still need to normalize and resize the images to the appropriate size.

# %%
# TODO: Load the dataset with TensorFlow Datasets.
# !python -m tensorflow_datasets.scripts.download_and_prepare --register_checksums=True --datasets=oxford_flowers102
ds, info = tfds.load("oxford_flowers102",with_info=True,download=True)
# TODO: Create a training set, a validation set and a test set.
training_data = ds['train']
testing_data = ds['test']
validation_data = ds['validation']
# Out:
# 2020-07-24 13:29:06.307620: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# I0724 13:29:08.840542 140352529860480 download_and_prepare.py:180] Running download_and_prepare for datasets:
# oxford_flowers102
# I0724 13:29:08.841282 140352529860480 download_and_prepare.py:181] Version: "None"
# I0724 13:29:08.842078 140352529860480 dataset_builder.py:202] Load pre-computed datasetinfo (eg: splits) from bucket.
# I0724 13:29:08.889947 140352529860480 dataset_info.py:431] Loading info from GCS for oxford_flowers102/2.0.0
# I0724 13:29:08.906715 140352529860480 dataset_info.py:403] Field info.description from disk and from code do not match. Keeping the one from code.
# I0724 13:29:08.907138 140352529860480 download_and_prepare.py:130] download_and_prepare for dataset oxford_flowers102/2.0.0...
# I0724 13:29:08.907579 140352529860480 dataset_builder.py:310] Generating dataset oxford_flowers102 (/root/tensorflow_datasets/oxford_flowers102/2.0.0)
# Downloading and preparing dataset oxford_flowers102/2.0.0 (download: 336.76 MiB, generated: Unknown size, total: 336.76 MiB) to /root/tensorflow_datasets/oxford_flowers102/2.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]I0724 13:29:08.979606 140352529860480 download_manager.py:256] Downloading https://www.robots.ox.ac.uk/~vgg/data/flowers/102/102flowers.tgz into /root/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_102flowersoWedSp98maBn1wypsDib6T-q2NVbO40fwvTflmPmQpY.tgz.tmp.a163a16a1490487fbf357ae56398c70c...
# Dl Completed...:   0% 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]I0724 13:29:08.980902 140352529860480 download_manager.py:246] URL https://www.robots.ox.ac.uk/~vgg/data/flowers/102/imagelabels.mat already downloaded: reusing /root/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_imagelabelSQPpQga6wjv3cqrfBkUZFt9WtY_Eg6YtsyqXuCZWZR0.mat.
# I0724 13:29:08.981604 140352529860480 download_manager.py:273] Skipping extraction for /root/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_imagelabelSQPpQga6wjv3cqrfBkUZFt9WtY_Eg6YtsyqXuCZWZR0.mat (method=NO_EXTRACT).
# I0724 13:29:08.983442 140352529860480 download_manager.py:246] URL https://www.robots.ox.ac.uk/~vgg/data/flowers/102/setid.mat already downloaded: reusing /root/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_setidRrhnj5H9ldPI9P6rgNJxpsg0od2Jb-Kf0-atnOXI3M0.mat.
# I0724 13:29:08.984005 140352529860480 download_manager.py:273] Skipping extraction for /root/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_setidRrhnj5H9ldPI9P6rgNJxpsg0od2Jb-Kf0-atnOXI3M0.mat (method=NO_EXTRACT).
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# Dl Completed...:   0% 0/1 [00:00<?, ? url/s]
# Dl Size...:   0% 0/328 [00:00<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   0% 1/328 [00:01<05:47,  1.06s/ MiB]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   1% 2/328 [00:01<04:13,  1.29 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   1% 3/328 [00:01<04:12,  1.29 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   1% 4/328 [00:01<03:01,  1.78 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   2% 5/328 [00:01<03:00,  1.78 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   2% 6/328 [00:01<02:11,  2.45 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   2% 7/328 [00:01<02:10,  2.45 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   2% 8/328 [00:01<01:36,  3.32 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   3% 9/328 [00:01<01:36,  3.32 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   3% 10/328 [00:01<01:11,  4.42 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   3% 11/328 [00:01<01:11,  4.42 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   4% 12/328 [00:01<01:11,  4.42 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   4% 13/328 [00:01<00:55,  5.66 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   4% 14/328 [00:01<00:55,  5.66 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   5% 15/328 [00:01<00:55,  5.66 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   5% 16/328 [00:01<00:41,  7.44 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   5% 17/328 [00:01<00:41,  7.44 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0% 0/1 [00:01<?, ? url/s]
# Dl Size...:   5% 18/328 [00:01<00:34,  9.03 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:   6% 19/328 [00:02<00:34,  9.03 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:   6% 20/328 [00:02<00:34,  9.03 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:   6% 21/328 [00:02<00:26, 11.39 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:   7% 22/328 [00:02<00:26, 11.39 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:   7% 23/328 [00:02<00:26, 11.39 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:   7% 24/328 [00:02<00:22, 13.73 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:   8% 25/328 [00:02<00:22, 13.73 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:   8% 26/328 [00:02<00:21, 13.73 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:   8% 27/328 [00:02<00:18, 16.29 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:   9% 28/328 [00:02<00:18, 16.29 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:   9% 29/328 [00:02<00:18, 16.29 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:   9% 30/328 [00:02<00:16, 18.53 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:   9% 31/328 [00:02<00:16, 18.53 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:  10% 32/328 [00:02<00:15, 18.53 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:  10% 33/328 [00:02<00:16, 18.14 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:  10% 34/328 [00:02<00:16, 18.14 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:  11% 35/328 [00:02<00:16, 18.14 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:  11% 36/328 [00:02<00:14, 20.44 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:  11% 37/328 [00:02<00:14, 20.44 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:  12% 38/328 [00:02<00:14, 20.44 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:  12% 39/328 [00:02<00:12, 22.35 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:  12% 40/328 [00:02<00:12, 22.35 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:  12% 41/328 [00:02<00:12, 22.35 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:  13% 42/328 [00:02<00:12, 23.29 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:02<?, ? url/s]
# Dl Size...:  13% 43/328 [00:02<00:12, 23.29 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  13% 44/328 [00:03<00:12, 23.29 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  14% 45/328 [00:03<00:11, 24.27 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  14% 46/328 [00:03<00:11, 24.27 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  14% 47/328 [00:03<00:11, 24.27 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  15% 48/328 [00:03<00:11, 25.19 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  15% 49/328 [00:03<00:11, 25.19 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  15% 50/328 [00:03<00:11, 25.19 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  16% 51/328 [00:03<00:10, 25.53 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  16% 52/328 [00:03<00:10, 25.53 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  16% 53/328 [00:03<00:10, 25.53 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  16% 54/328 [00:03<00:10, 25.37 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  17% 55/328 [00:03<00:10, 25.37 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  17% 56/328 [00:03<00:10, 25.37 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  17% 57/328 [00:03<00:10, 26.45 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  18% 58/328 [00:03<00:10, 26.45 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  18% 59/328 [00:03<00:10, 26.45 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  18% 60/328 [00:03<00:09, 27.00 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  19% 61/328 [00:03<00:09, 27.00 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  19% 62/328 [00:03<00:09, 27.00 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0% 0/1 [00:03<?, ? url/s]
# Dl Size...:  19% 63/328 [00:03<00:09, 27.14 MiB/s]
#
# Dl Completed...:   0% 0/1 [00
MiB/s]
#
# Dl Completed...:   0% 0/1 [00:13<?, ? url/s]
# Dl Size...:  99% 326/328 [00:13<00:00, 27.40 MiB/s]
#
# Extraction completed...: 0 file [00:13, ? file/s]
# Dl Completed...:   0% 0/1 [00:13<?, ? url/s]
# Dl Size...: 100% 327/328 [00:13<00:00, 27.14 MiB/s]
#
# Dl Completed...:   0% 0/1 [00:13<?, ? url/s]
# Dl Size...: 100% 328/328 [00:13<00:00, 27.14 MiB/s]
#
# Dl Completed...: 100% 1/1 [00:13<00:00, 13.51s/ url]
# Dl Size...: 100% 328/328 [00:13<00:00, 27.14 MiB/s]
#
# Dl Completed...: 100% 1/1 [00:13<00:00, 13.51s/ url]
# Dl Size...: 100% 328/328 [00:13<00:00, 27.14 MiB/s]
#
# Extraction completed...:   0% 0/1 [00:13<?, ? file/s]
#
# Dl Completed...: 100% 1/1 [00:18<00:00, 13.51s/ url]
# Dl Size...: 100% 328/328 [00:18<00:00, 27.14 MiB/s]
#
# Extraction completed...: 100% 1/1 [00:18<00:00, 18.99s/ file]
# Extraction completed...: 100% 1/1 [00:18<00:00, 18.99s/ file]
#
# Dl Size...: 100% 328/328 [00:18<00:00, 17.28 MiB/s]
#
# Dl Completed...: 100% 1/1 [00:18<00:00, 18.99s/ url]
# I0724 13:29:27.966068 140352529860480 dataset_builder.py:927] Generating split train
# Shuffling and writing examples to /root/tensorflow_datasets/oxford_flowers102/2.0.0.incompleteIRVZ5H/oxford_flowers102-train.tfrecord
#   0% 0/1020 [00:00<?, ? examples/s]I0724 13:29:28.766060 140352529860480 tfrecords_writer.py:228] Done writing /root/tensorflow_datasets/oxford_flowers102/2.0.0.incompleteIRVZ5H/oxford_flowers102-train.tfrecord. Shard lengths: [1020]
# I0724 13:29:28.772452 140352529860480 dataset_builder.py:927] Generating split test
# Shuffling and writing examples to /root/tensorflow_datasets/oxford_flowers102/2.0.0.incompleteIRVZ5H/oxford_flowers102-test.tfrecord
#  96% 5929/6149 [00:01<00:00, 3980.70 examples/s]I0724 13:29:36.583022 140352529860480 tfrecords_writer.py:228] Done writing /root/tensorflow_datasets/oxford_flowers102/2.0.0.incompleteIRVZ5H/oxford_flowers102-test.tfrecord. Shard lengths: [3074, 3075]
# I0724 13:29:36.623083 140352529860480 dataset_builder.py:927] Generating split validation
# Shuffling and writing examples to /root/tensorflow_datasets/oxford_flowers102/2.0.0.incompleteIRVZ5H/oxford_flowers102-validation.tfrecord
#   0% 0/1020 [00:00<?, ? examples/s]I0724 13:29:37.281790 140352529860480 tfrecords_writer.py:228] Done writing /root/tensorflow_datasets/oxford_flowers102/2.0.0.incompleteIRVZ5H/oxford_flowers102-validation.tfrecord. Shard lengths: [1020]
# I0724 13:29:37.288176 140352529860480 dataset_builder.py:359] Computing statistics.
# Computing statistics...:   0% 0/3 [00:00<?, ? split/s]I0724 13:29:37.289255 140352529860480 dataset_builder.py:458] Constructing tf.data.Dataset for split test, from /root/tensorflow_datasets/oxford_flowers102/2.0.0.incompleteIRVZ5H
# 2020-07-24 13:29:37.347408: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-24 13:29:37.444482: E tensorflow/stream_executor/cuda/cuda_driver.cc:313] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-24 13:29:37.444603: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (78a943319b04): /proc/driver/nvidia/version does not exist
# 2020-07-24 13:29:37.480561: I tensorflow/core/platform/profile_utils/cpu_utils.cc:102] CPU Frequency: 2300000000 Hz
# 2020-07-24 13:29:37.481032: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x136f480 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-24 13:29:37.481076: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#
# 0 examples [00:00, ? examples/s]
# 1 examples [00:00,  5.44 examples/s]
# 32 examples [00:00,  7.71 examples/s]
# 65 examples [00:00, 10.91 examples/s]
# 96 examples [00:00, 15.34 examples/s]
# 133 examples [00:00, 21.53 examples/s]
# 166 examples [00:00, 29.91 examples/s]
# 199 examples [00:00, 41.11 examples/s]
# 234 examples [00:00, 55.88 examples/s]
# 267 examples [00:00, 74.40 examples/s]
# 300 examples [00:01, 96.67 examples/s]
# 332 examples [00:01, 120.82 examples/s]
# 363 examples [00:01, 146.62 examples/s]
# 394 examples [00:01, 173.60 examples/s]
# 425 examples [00:01, 199.85 examples/s]
# 456 examples [00:01, 222.57 examples/s]
# 489 examples [00:01, 245.73 examples/s]
# 526 examples [00:01, 272.64 examples/s]
# 561 examples [00:01, 291.47 examples/s]
# 595 examples [00:02, 302.17 examples/s]
# 633 examples [00:02, 319.14 examples/s]
# 668 examples [00:02, 314.02 examples/s]
# 705 examples [00:02, 327.31 examples/s]
# 740 examples [00:02, 331.02 examples/s]
# 775 examples [00:02, 315.01 examples/s]
# 808 examples [00:02, 316.08 examples/s]
# 841 examples [00:02, 314.27 examples/s]
# 873 examples [00:02, 297.05 examples/s]
# 904 examples [00:03, 296.81 examples/s]
# 935 examples [00:03, 292.38 examples/s]
# 965 examples [00:03, 281.80 examples/s]
# 994 examples [00:03, 282.25 examples/s]
# 1024 examples [00:03, 285.69 examples/s]
# 1053 examples [00:03, 282.64 examples/s]
# 1084 examples [00:03, 288.26 examples/s]
# 1113 examples [00:03, 286.96 examples/s]
# 1142 examples [00:03, 282.50 examples/s]
# 1172 examples [00:03, 287.47 examples/s]
# 1201 examples [00:04, 281.65 examples/s]
# 1230 examples [00:04, 278.36 examples/s]
# 1258 examples [00:04, 271.98 examples/s]
# 1289 examples [00:04, 281.06 examples/s]
# 1319 examples [00:04, 283.56 examples/s]
# 1348 examples [00:04, 284.10 examples/s]
# 1379 examples [00:04, 290.54 examples/s]
# 1409 examples [00:04, 289.57 examples/s]
# 1447 examples [00:04, 310.81 examples/s]
# 1479 examples [00:04, 309.69 examples/s]
# 1511 examples [00:05, 311.68 examples/s]
# 1543 examples [00:05, 307.03 examples/s]
# 1574 examples [00:05, 302.74 examples/s]
# 1605 examples [00:05, 296.57 examples/s]
# 1639 examples [00:05, 306.37 examples/s]
# 1671 examples [00:05, 307.62 examples/s]
# 1705 examples [00:05, 316.01 examples/s]
# 1737 examples [00:05, 284.81 examples/s]
# 1767 examples [00:05, 288.40 examples/s]
# 1800 examples [00:06, 297.40 examples/s]
# 1833 examples [00:06, 302.25 examples/s]
# 1864 examples [00:06, 289.07 examples/s]
# 1894 examples [00:06, 285.22 examples/s]
# 1923 examples [00:06, 278.71 examples/s]
# 1952 examples [00:06, 279.43 examples/s]
# 1984 examples [00:06, 288.69 examples/s]
# 2014 examples [00:06, 289.12 examples/s]
# 2044 examples [00:06, 282.98 examples/s]
# 4161 examples [00:14, 299.80 examples/s]
# 4193 examples [00:14, 303.44 examples/s]
# 4225 examples [00:14, 306.29 examples/s]
# 4256 examples [00:14, 301.47 examples/s]
# 4287 examples [00:14, 299.63 examples/s]
# 4322 examples [00:14, 311.58 examples/s]
# 4360 examples [00:14, 329.01 examples/s]
# 4394 examples [00:14, 331.57 examples/s]
# 4428 examples [00:14, 327.04 examples/s]
# 4461 examples [00:15, 325.73 examples/s]
# 4494 examples [00:15, 313.95 examples/s]
# 4526 examples [00:15, 314.67 examples/s]
# 4558 examples [00:15, 312.51 examples/s]
# 4590 examples [00:15, 306.88 examples/s]
# 4621 examples [00:15, 306.23 examples/s]
# 4652 examples [00:15, 306.22 examples/s]
# 4684 examples [00:15, 308.62 examples/s]
# 4718 examples [00:15, 314.56 examples/s]
# 4750 examples [00:15, 301.71 examples/s]
# 4782 examples [00:16, 306.75 examples/s]
# 4814 examples [00:16, 309.82 examples/s]
# 4846 examples [00:16, 310.48 examples/s]
# 4879 examples [00:16, 315.40 examples/s]
# 4911 examples [00:16, 306.81 examples/s]
# 4947 examples [00:16, 318.84 examples/s]
# 4981 examples [00:16, 324.71 examples/s]
# 5015 examples [00:16, 326.71 examples/s]
# 5049 examples [00:16, 329.50 examples/s]
# 5083 examples [00:17, 315.91 examples/s]
# 5115 examples [00:17, 311.80 examples/s]
# 5148 examples [00:17, 316.26 examples/s]
# 5181 examples [00:17, 319.42 examples/s]
# 5215 examples [00:17, 324.18 examples/s]
# 5248 examples [00:17, 311.38 examples/s]
# 5280 examples [00:17, 312.58 examples/s]
# 5315 examples [00:17, 322.28 examples/s]
# 5348 examples [00:17, 322.36 examples/s]
# 5381 examples [00:17, 319.21 examples/s]
# 5415 examples [00:18, 322.89 examples/s]
# 5448 examples [00:18, 314.39 examples/s]
# 5481 examples [00:18, 315.89 examples/s]
# 5514 examples [00:18, 317.46 examples/s]
# 5546 examples [00:18, 306.73 examples/s]
# 5581 examples [00:18, 317.82 examples/s]
# 5613 examples [00:18, 316.28 examples/s]
# 5650 examples [00:18, 328.41 examples/s]
# 5684 examples [00:18, 330.02 examples/s]
# 5719 examples [00:18, 333.69 examples/s]
# 5753 examples [00:19, 321.29 examples/s]
# 5786 examples [00:19, 315.30 examples/s]
# 5819 examples [00:19, 318.73 examples/s]
# 5851 examples [00:19, 317.30 examples/s]
# 5883 examples [00:19, 312.62 examples/s]
# 5918 examples [00:19, 320.96 examples/s]
# 5951 examples [00:19, 317.38 examples/s]
# 5983 examples [00:19, 301.57 examples/s]
# 6014 examples [00:19, 292.54 examples/s]
# 6044 examples [00:20, 293.52 examples/s]
# 6074 examples [00:20, 289.41 examples/s]
# 6104 examples [00:20, 287.84 examples/s]
# 6135 examples [00:20, 292.46 examples/s]
# Computing statistics...:  33% 1/3 [00:20<00:41, 20.78s/ split]I0724 13:29:58.072670 140352529860480 dataset_builder.py:458] Constructing tf.data.Dataset for split train, from /root/tensorflow_datasets/oxford_flowers102/2.0.0.incompleteIRVZ5H
#
# 0 examples [00:00, ? examples/s]
# 11 examples [00:00, 104.24 examples/s]
# 38 examples [00:00, 127.70 examples/s]
# 66 examples [00:00, 152.52 examples/s]
# 95 examples [00:00, 176.16 examples/s]
# 123 examples [00:00, 197.67 examples/s]
# 145 examples [00:00, 201.41 examples/s]
# 173 examples [00:00, 219.72 examples/s]
# 204 examples [00:00, 239.61 examples/s]
# 232 examples [00:00, 249.46 examples/s]
# 259 examples [00:01, 253.60 examples/s]
# 290 examples [00:01, 265.62 examples/s]
# 322 examples [00:01, 279.70 examples/s]
# 359 examples [00:01, 300.65 examples/s]
# 392 examples [00:01, 306.83 examples/s]
# 426 examples [00:01, 314.51 examples/s]
# 459 examples [00:01, 318.45 examples/s]
# 497 examples [00:01, 333.25 examples/s]
# 531 examples [00:01, 331.92 examples/s]
# 565 examples [00:01, 332.57 examples/s]
# 599 examples [00:02, 333.83 examples/s]
# 633 examples [00:02, 325.54 examples/s]
# 666 examples [00:02, 320.54 examples/s]
# 699 examples [00:02, 318.29 examples/s]
# 731 examples [00:02, 308.37 examples/s]
# 762 examples [00:02, 293.72 examples/s]
# 792 examples [00:02, 290.76 examples/s]
# 822 examples [00:02, 289.28 examples/s]
# 855 examples [00:02, 297.89 examples/s]
# 885 examples [00:03, 296.66 examples/s]
# 915 examples [00:03, 290.67 examples/s]
# 946 examples [00:03, 294.24 examples/s]
# 977 examples [00:03, 297.85 examples/s]
# 1007 examples [00:03, 290.62 examples/s]
# Computing statistics...:  67% 2/3 [00:24<00:15, 15.62s/ split]I0724 13:30:01.652931 140352529860480 dataset_builder.py:458] Constructing tf.data.Dataset for split validation, from /root/tensorflow_datasets/oxford_flowers102/2.0.0.incompleteIRVZ5H
#
# 0 examples [00:00, ? examples/s]
# 7 examples [00:00, 68.05 examples/s]
# 32 examples [00:00, 86.89 examples/s]
# 59 examples [00:00, 109.02 examples/s]
# 88 examples [00:00, 133.69 examples/s]
# 112 examples [00:00, 153.72 examples/s]
# 139 examples [00:00, 176.10 examples/s]
# 171 examples [00:00, 203.22 examples/s]
# 206 examples [00:00, 232.36 examples/s]
# 244 examples [00:00, 261.93 examples/s]
# 277 examples [00:01, 278.08 examples/s]
# 311 examples [00:01, 292.85 examples/s]
# 349 examples [00:01, 311.89 examples/s]
# 383 examples [00:01, 314.64 examples/s]
# 417 examples [00:01, 320.72 examples/s]
# 451 examples [00:01, 316.02 examples/s]
# 488 examples [00:01, 330.33 examples/s]
# 524 examples [00:01, 338.64 examples/s]
# 559 examples [00:01, 338.75 examples/s]
# 595 examples [00:01, 342.84 examples/s]
# 633 examples [00:02, 352.80 examples/s]
# 669 examples [00:02, 347.91 examples/s]
# 704 examples [00:02, 345.69 examples/s]
# 740 examples [00:02, 347.69 examples/s]
# 775 examples [00:02, 347.27 examples/s]
# 810 examples [00:02, 344.67 examples/s]
# 845 examples [00:02, 333.60 examples/s]
# 879 examples [00:02, 330.37 examples/s]
# 913 examples [00:02, 321.77 examples/s]
# 946 examples [00:03, 305.71 examples/s]
# 977 examples [00:03, 297.13 examples/s]
# 1010 examples [00:03, 305.64 examples/s]
# Computing statistics...: 100% 3/3 [00:27<00:00,  9.24s/ split]
# Dataset oxford_flowers102 downloaded and prepared to /root/tensorflow_datasets/oxford_flowers102/2.0.0. Subsequent calls will reuse this data.
# name: "oxford_flowers102"
# description: "\nThe Oxford Flowers 102 dataset is a consistent of 102 flower categories commonly occurring\nin the United Kingdom. Each class consists of between 40 and 258 images. The images have\nlarge scale, pose and light variations. In addition, there are categories that have large\nvariations within the category and several very similar categories.\n\nThe dataset is divided into a training set, a validation set and a test set.\nThe training set and validation set each consist of 10 images per class (totalling 1020 images each).\nThe test set consists of the remaining 6149 images (minimum 20 per class).\n"
# citation: "@InProceedings{Nilsback08,\n   author = \"Nilsback, M-E. and Zisserman, A.\",\n   title = \"Automated Flower Classification over a Large Number of Classes\",\n   booktitle = \"Proceedings of the Indian Conference on Computer Vision, Graphics and Image Processing\",\n   year = \"2008\",\n   month = \"Dec\"\n}\n"
# size_in_bytes: 353121411
# location {
#   urls: "https://www.robots.ox.ac.uk/~vgg/data/flowers/102/"
# }
# schema {
#   feature {
#     name: "file_name"
#     type: BYTES
#   }
#   feature {
#     name: "image"
#     type: INT
#     shape {
#       dim {
#         size: -1
#       }
#       dim {
#         size: -1
#       }
#       dim {
#         size: 3
#       }
#     }
#   }
#   feature {
#     name: "label"
#     type: INT
#   }
# }
# splits {
#   name: "test"
#   num_shards: 1
#   statistics {
#     num_examples: 6149
#     features {
#       name: "file_name"
#       type: BYTES
#       bytes_stats {
#         common_stats {
#           num_non_missing: 6149
#         }
#       }
#     }
#     features {
#       name: "image"
#       num_stats {
#         common_stats {
#           num_non_missing: 6149
#         }
#         max: 255.0
#       }
#     }
#     features {
#       name: "label"
#       num_stats {
#         common_stats {
#           num_non_missing: 6149
#         }
#         max: 101.0
#       }
#     }
#   }
#   shard_lengths: 3074
#   shard_lengths: 3075
#   num_bytes: 260784877
# }
# splits {
#   name: "train"
#   num_shards: 1
#   statistics {
#     num_examples: 1020
#     features {
#       name: "file_name"
#       type: BYTES
#       bytes_stats {
#         common_stats {
#           num_non_missing: 1020
#         }
#       }
#     }
#     features {
#       name: "image"
#       num_stats {
#         common_stats {
#           num_non_missing: 1020
#         }
#         max: 255.0
#       }
#     }
#     features {
#       name: "label"
#       num_stats {
#         common_stats {
#           num_non_missing: 1020
#         }
#         max: 101.0
#       }
#     }
#   }
#   shard_lengths: 1020
#   num_bytes: 43474584
# }
# splits {
#   name: "validation"
#   num_shards: 1
#   statistics {
#     num_examples: 1020
#     features {
#       name: "file_name"
#       type: BYTES
#       bytes_stats {
#         common_stats {
#           num_non_missing: 1020
#         }
#       }
#     }
#     features {
#       name: "image"
#       num_stats {
#         common_stats {
#           num_non_missing: 1020
#         }
#         max: 255.0
#       }
#     }
#     features {
#       name: "label"
#       num_stats {
#         common_stats {
#           num_non_missing: 1020
#         }
#         max: 101.0
#       }
#     }
#   }
#   shard_lengths: 1020
#   num_bytes: 43180278
# }
# supervised_keys {
#   input: "image"
#   output: "label"
# }
# version: "2.0.0"
# download_size: 344878000

# %% [markdown]
# ## Explore the Dataset

# %%
# TODO: Get the number of examples in each set from the dataset info.
train_ex = info.splits['train'].num_examples
test_ex = info.splits['test'].num_examples
validation_ex = info.splits['validation'].num_examples
print("total ",train_ex," images in the training set")
print("total ",test_ex," images in the testing set")
print("total ",validation_ex," images in the validation set")

# TODO: Get the number of classes in the dataset from the dataset info.
num_classes = info.features['label'].num_classes
#print the total number of classes
print("total ",num_classes," classes in this data set")
# Out:
# total  1020  images in the training set
# total  6149  images in the testing set
# total  1020  images in the validation set
# total  102  classes in this data set

# %%
# TODO: Print the shape and corresponding label of 3 images in the training set.
for img in training_data.take(3):
    image,label,shape = img['image'], img['label'], img['image'].shape
    #print("image label is : ",label," image shape is : " ,shape)
    print(('Image label is : {0} and shape is : {1}').format(label,shape))
# Out:
# Image label is : 72 and shape is : (500, 667, 3)
# Image label is : 84 and shape is : (500, 666, 3)
# Image label is : 70 and shape is : (670, 500, 3)

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding image label. 
for img in training_data.take(1):
    image,label = img['image'], img['label']
    plt.imshow(image.numpy())
    plt.title(label.numpy())

# %% [markdown]
# ### Label Mapping
#
# You'll also need to load in a mapping from label to category name. You can find this in the file `label_map.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/3.7/library/json.html). This will give you a dictionary mapping the integer coded labels to the actual names of the flowers.

# %%
with open('label_map.json', 'r') as f:
    class_names = json.load(f)

# %%
class_names_new = dict()
for key in class_names:
    class_names_new[str(int(key)-1)] = class_names[key]

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding class name. 
for img in training_data.take(1):
    image,label = img['image'], img['label']
    plt.imshow(image.numpy())
    plt.title(class_names_new[str(label.numpy())])

# %% [markdown]
# ## Create Pipeline

# %%
# TODO: Create a pipeline for each set.
IMAGE_SHAPE = (224,224,3)

# %% [markdown]
# # Build and Train the Classifier
#
# Now that the data is ready, it's time to build and train the classifier. You should use the MobileNet pre-trained model from TensorFlow Hub to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students!
#
# Refer to the rubric for guidance on successfully completing this section. Things you'll need to do:
#
# * Load the MobileNet pre-trained network from TensorFlow Hub.
# * Define a new, untrained feed-forward network as a classifier.
# * Train the classifier.
# * Plot the loss and accuracy values achieved during training for the training and validation set.
# * Save your trained model as a Keras model.
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right.
#
# **Note for Workspace users:** One important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module. Also, If your model is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network.
mobilenet_class_map_file = "download.tensorflow.org/data/ImageNetLabels.txt"
feature_url = "https://tfhub.dev/google/imagenet/mobilenet_v1_050_160/classification/4"
feature_layer = hub.KerasLayer(feature_url, input_shape=IMAGE_SHAPE, trainable=False)
model = tf.keras.Sequential([feature_layer,
                                 tf.keras.layers.Dense(600,activation='relu'),
                                 tf.keras.layers.Dropout(0.2),
                                 tf.keras.layers.Dense(300,activation='relu'),
                                 tf.keras.layers.Dropout(0.2),
                                 tf.keras.layers.Dense(num_classes, activation='softmax')
                                ])
print(model.summary())

def format_image(img):
    label = img['label']
    label = tf.one_hot(label,num_classes)
    img = img['image']

    processed_image = tf.image.resize(img,(224, 224))
    processed_image /= 255
    
    return processed_image, label

BATCH_SIZE = 32
training_batches = training_data.shuffle(train_ex//4).map(format_image).batch(BATCH_SIZE).prefetch(1)
validation_batches = validation_data.shuffle(train_ex//4).map(format_image).batch(BATCH_SIZE).prefetch(1)
test_batches = testing_data.shuffle(train_ex//4).map(format_image).batch(BATCH_SIZE).prefetch(1)
callback_path = "Trained Model/Weights"+"/best_weights.hdf5"
checkpoint = tf.keras.callbacks.ModelCheckpoint(callback_path, save_best_only=True, save_weights_only=False)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss='categorical_crossentropy',
                  metrics=['acc'])
hist_call_back = model.fit(training_batches, epochs=30, callbacks=[checkpoint], validation_data=validation_batches)
model, hist_call_back
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1001)              1343049
# _________________________________________________________________
# dense_27 (Dense)             (None, 600)               601200
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 600)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 300)               180300
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 300)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 102)               30702
# =================================================================
# Total params: 2,155,251
# Trainable params: 812,202
# Non-trainable params: 1,343,049
# _________________________________________________________________
# None
# Epoch 1/30
# 32/32 [==============================] - 37s 1s/step - loss: 5.6140 - acc: 0.0235 - val_loss: 4.4231 - val_acc: 0.0578
# Epoch 2/30
# 32/32 [==============================] - 36s 1s/step - loss: 4.3466 - acc: 0.0686 - val_loss: 4.0734 - val_acc: 0.1314
# Epoch 3/30
# 32/32 [==============================] - 37s 1s/step - loss: 3.9298 - acc: 0.1059 - val_loss: 3.7120 - val_acc: 0.2353
# Epoch 4/30
# 32/32 [==============================] - 38s 1s/step - loss: 3.5195 - acc: 0.2127 - val_loss: 3.3202 - val_acc: 0.3363
# Epoch 5/30
# 32/32 [==============================] - 37s 1s/step - loss: 3.1380 - acc: 0.2716 - val_loss: 2.9637 - val_acc: 0.3931
# Epoch 6/30
# 32/32 [==============================] - 36s 1s/step - loss: 2.7141 - acc: 0.3598 - val_loss: 2.6369 - val_acc: 0.4716
# Epoch 7/30
# 32/32 [==============================] - 36s 1s/step - loss: 2.3416 - acc: 0.4539 - val_loss: 2.3623 - val_acc: 0.5020
# Epoch 8/30
# 32/32 [==============================] - 36s 1s/step - loss: 2.0123 - acc: 0.5294 - val_loss: 2.1125 - val_acc: 0.5588
# Epoch 9/30
# 32/32 [==============================] - 36s 1s/step - loss: 1.7815 - acc: 0.5735 - val_loss: 1.9476 - val_acc: 0.5667
# Epoch 10/30
# 32/32 [==============================] - 38s 1s/step - loss: 1.6085 - acc: 0.6176 - val_loss: 1.7926 - val_acc: 0.6049
# Epoch 11/30
# 32/32 [==============================] - 37s 1s/step - loss: 1.3988 - acc: 0.6627 - val_loss: 1.6783 - val_acc: 0.6039
# Epoch 12/30
# 32/32 [==============================] - 37s 1s/step - loss: 1.2453 - acc: 0.6961 - val_loss: 1.5618 - val_acc: 0.6294
# Epoch 13/30
# 32/32 [==============================] - 37s 1s/step - loss: 1.1004 - acc: 0.7471 - val_loss: 1.5036 - val_acc: 0.6431
# Epoch 14/30
# 32/32 [==============================] - 37s 1s/step - loss: 0.9389 - acc: 0.7755 - val_loss: 1.4073 - val_acc: 0.6627
# Epoch 15/30
# 32/32 [==============================] - 37s 1s/step - loss: 0.8651 - acc: 0.8020 - val_loss: 1.3478 - val_acc: 0.6657
# Epoch 16/30
# 32/32 [==============================] - 36s 1s/step - loss: 0.7708 - acc: 0.8127 - val_loss: 1.2979 - val_acc: 0.6765
# Epoch 17/30
# 32/32 [==============================] - 36s 1s/step - loss: 0.7035 - acc: 0.8255 - val_loss: 1.2664 - val_acc: 0.6902
# Epoch 18/30
# 32/32 [==============================] - 37s 1s/step - loss: 0.6606 - acc: 0.8343 - val_loss: 1.2269 - val_acc: 0.7029
# Epoch 19/30
# 32/32 [==============================] - 37s 1s/step - loss: 0.6047 - acc: 0.8637 - val_loss: 1.1782 - val_acc: 0.7049
# Epoch 20/30
# 32/32 [==============================] - 37s 1s/step - loss: 0.5181 - acc: 0.8902 - val_loss: 1.1504 - val_acc: 0.7078
# Epoch 21/30
# 32/32 [==============================] - 36s 1s/step - loss: 0.4994 - acc: 0.8843 - val_loss: 1.1347 - val_acc: 0.7078
# Epoch 22/30
# 32/32 [==============================] - 36s 1s/step - loss: 0.4478 - acc: 0.8961 - val_loss: 1.1061 - val_acc: 0.7147
# Epoch 23/30
# 32/32 [==============================] - 36s 1s/step - loss: 0.4161 - acc: 0.9059 - val_loss: 1.0906 - val_acc: 0.7069
# Epoch 24/30
# 32/32 [==============================] - 36s 1s/step - loss: 0.3566 - acc: 0.9294 - val_loss: 1.0776 - val_acc: 0.7255
# Epoch 25/30
# 32/32 [==============================] - 37s 1s/step - loss: 0.3450 - acc: 0.9324 - val_loss: 1.0510 - val_acc: 0.7216
# Epoch 26/30
# 32/32 [==============================] - 37s 1s/step - loss: 0.2882 - acc: 0.9471 - val_loss: 1.0469 - val_acc: 0.7265
# Epoch 27/30
# 32/32 [==============================] - 36s 1s/step - loss: 0.3043 - acc: 0.9304 - val_loss: 1.0231 - val_acc: 0.7373
# Epoch 28/30
# 32/32 [==============================] - 38s 1s/step - loss: 0.2533 - acc: 0.9520 - val_loss: 1.0011 - val_acc: 0.7382
# Epoch 29/30
# 32/32 [==============================] - 37s 1s/step - loss: 0.2641 - acc: 0.9451 - val_loss: 1.0162 - val_acc: 0.7373
# Epoch 30/30
# 32/32 [==============================] - 36s 1s/step - loss: 0.2570 - acc: 0.9480 - val_loss: 1.0093 - val_acc: 0.7373
# (<tensorflow.python.keras.engine.sequential.Sequential at 0x7f41ebad4748>,
#  <tensorflow.python.keras.callbacks.History at 0x7f41e3832630>)

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.
training_accuracy = hist_call_back.history['acc']
validation_accuracy = hist_call_back.history['val_acc']

training_loss = hist_call_back.history['loss']
validation_loss = hist_call_back.history['val_loss']

epochs_range=range(30)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Testing your Network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Print the loss and accuracy values achieved on the entire test set.
loss, accuracy = model.evaluate(test_batches)
print('\nLoss on the TEST Set: {:,.3f}'.format(loss))
print('Accuracy on the TEST Set: {:.3%}'.format(accuracy))
# Out:
# 193/193 [==============================] - 112s 583ms/step - loss: 1.0841 - acc: 0.7209
#
# Loss on the TEST Set: 1.084
# Accuracy on the TEST Set: 72.093%

# %% [markdown]
# ## Save the Model
#
# Now that your network is trained, save the model so you can load it later for making inference. In the cell below save your model as a Keras model (*i.e.* save it as an HDF5 file).

# %%
# TODO: Save your trained model as a Keras model.
model_path = 'Trained Model/TrainedModel.h5'
model.save(model_path)

# %% [markdown]
# ## Load the Keras Model
#
# Load the Keras model you saved above.

# %%
# TODO: Load the Keras model
tf.keras.backend.clear_session()
loaded_model = tf.keras.models.load_model(model_path,custom_objects={'KerasLayer':hub.KerasLayer})
loaded_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1001)              1343049
# _________________________________________________________________
# dense_27 (Dense)             (None, 600)               601200
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 600)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 300)               180300
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 300)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 102)               30702
# =================================================================
# Total params: 2,155,251
# Trainable params: 812,202
# Non-trainable params: 1,343,049
# _________________________________________________________________

# %% [markdown]
# # Inference for Classification
#
# Now you'll write a function that uses your trained network for inference. Write a function called `predict` that takes an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# The `predict` function will also need to handle pre-processing the input image such that it can be used by your model. We recommend you write a separate function called `process_image` that performs the pre-processing. You can then call the `process_image` function from the `predict` function.
#
# ### Image Pre-processing
#
# The `process_image` function should take in an image (in the form of a NumPy array) and return an image in the form of a NumPy array with shape `(224, 224, 3)`.
#
# First, you should convert your image into a TensorFlow Tensor and then resize it to the appropriate size using `tf.image.resize`.
#
# Second, the pixel values of the input images are typically encoded as integers in the range 0-255, but the model expects the pixel values to be floats in the range 0-1. Therefore, you'll also need to normalize the pixel values.
#
# Finally, convert your image back to a NumPy array using the `.numpy()` method.

# %%
# TODO: Create the process_image function
def process_image(numpy_image):
    print(numpy_image.shape)
    tensor_img = tf.image.convert_image_dtype(numpy_image, dtype=tf.int16, saturate=False)
    resized_img = tf.image.resize(numpy_image,(224, 224)).numpy()
    norm_img = resized_img/255

    return norm_img

# %% [markdown]
# To check your `process_image` function we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# The code below loads one of the above images using `PIL` and plots the original image alongside the image produced by your `process_image` function. If your `process_image` function works, the plotted image should be the correct size.

# %%
from PIL import Image

image_path = './test_images/hard-leaved_pocket_orchid.jpg'
im = Image.open(image_path)
test_image = np.asarray(im)

processed_test_image = process_image(test_image)

fig, (ax1, ax2) = plt.subplots(figsize=(10,10), ncols=2)
ax1.imshow(test_image)
ax1.set_title('Original Image')
ax2.imshow(processed_test_image)
ax2.set_title('Processed Image')
plt.tight_layout()
plt.show()
# Out:
# (591, 500, 3)

# %% [markdown]
# Once you can get images in the correct format, it's time to write the `predict` function for making inference with your model.
#
# ### Inference
#
# Remember, the `predict` function should take an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# **Note:** The image returned by the `process_image` function is a NumPy array with shape `(224, 224, 3)` but the model expects the input images to be of shape `(1, 224, 224, 3)`. This extra dimension represents the batch size. We suggest you use the `np.expand_dims()` function to add the extra dimension.

# %%
# TODO: Create the predict function
def predict(image_path, model, top_k):
    
    img = Image.open(image_path)
    test_image = np.asarray(img)

    processed_test_image = process_image(test_image)

    print(processed_test_image.shape, np.expand_dims(processed_test_image,axis=0).shape)
    prob_preds = model.predict(np.expand_dims(processed_test_image,axis=0))
    prob_preds = prob_preds[0].tolist()
#TODO: make these changes in the command line code as well
    values, indices= tf.math.top_k(prob_preds, k=top_k)
    probs=values.numpy().tolist()#[0]
    classes=indices.numpy().tolist()#[0]

    return probs, classes

# %% [markdown]
# # Sanity Check
#
# It's always good to check the predictions made by your model to make sure they are correct. To check your predictions we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# In the cell below use `matplotlib` to plot the input image alongside the probabilities for the top 5 classes predicted by your model. Plot the probabilities as a bar graph. The plot should look like this:
#
# <img src='assets/inference_example.png' width=600px>
#
# You can convert from the class integer labels to actual flower names using `class_names`.

# %%
# TODO: Plot the input image along with the top 5 classes
img_1 = './test_images/orange_dahlia.jpg'
img_2 = './test_images/wild_pansy.jpg'
img_3 = './test_images/hard-leaved_pocket_orchid.jpg'
img_4 = './test_images/cautleya_spicata.jpg'
def plot_image(path, index):
    ax = plt.subplot(2, 2, index*2 + 1)
    
    img = Image.open(path)
    test_image = np.asarray(img)
    img = process_image(test_image)
    
    title = path.rsplit("/",1)[-1]
    plt.title(title)
    plt.imshow(img)
    
    # Make prediction
    probs, labels = predict(path, model, 5)
    print(probs)
    print(labels)
    
    # Get label names
    label_names = [class_names_new[str(idd)] for idd in labels]
    print(label_names)
    
    # Plot bar chart
    ax = plt.subplot(2, 2, index*2 + 2)
    ax.yaxis.tick_right()
    sns.barplot(x=probs, y=label_names, color=sns.color_palette()[0]);

# %%
plt.figure(figsize = (6,10))
plot_image(img_1, 0)
plot_image(img_2, 1)
plt.show()
# Out:
# (752, 500, 3)
# (752, 500, 3)
# (224, 224, 3) (1, 224, 224, 3)
# [0.4776356518268585, 0.16856765747070312, 0.10454443097114563, 0.09274975210428238, 0.053185008466243744]
# [58, 4, 40, 99, 70]
# ['orange dahlia', 'english marigold', 'barbeton daisy', 'blanket flower', 'gazania']
# (558, 500, 3)
# (558, 500, 3)
# (224, 224, 3) (1, 224, 224, 3)
# [0.9727113246917725, 0.006834408268332481, 0.001919264905154705, 0.0017487667500972748, 0.0014984658919274807]
# [51, 47, 65, 64, 66]
# ['wild pansy', 'buttercup', 'osteospermum', 'californian poppy', 'spring crocus']

# %%
plt.figure(figsize = (6,10))
plot_image(img_3, 0)
plot_image(img_4, 1)
plt.show()
# Out:
# (591, 500, 3)
# (591, 500, 3)
# (224, 224, 3) (1, 224, 224, 3)
# [0.9992662072181702, 0.00028787250630557537, 0.0001875810557976365, 0.00012646806135307997, 5.768474511569366e-05]
# [1, 79, 6, 30, 2]
# ['hard-leaved pocket orchid', 'anthurium', 'moon orchid', 'carnation', 'canterbury bells']
# (750, 500, 3)
# (750, 500, 3)
# (224, 224, 3) (1, 224, 224, 3)
# [0.9353267550468445, 0.036851655691862106, 0.01517269667237997, 0.0031625116243958473, 0.001563029596582055]
# [60, 100, 20, 7, 12]
# ['cautleya spicata', 'trumpet creeper', 'fire lily', 'bird of paradise', 'king protea']
